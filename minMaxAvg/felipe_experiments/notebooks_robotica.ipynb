# %%
# %pip install seaborn

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
experiments = os.listdir("./experiments")
data_frames = []
names = [] 
for x in range(len(experiments)-1):
    experiment_name = experiments[x]
    experiment_name = experiment_name.replace('.csv', '')
    df = pd.read_csv(f"./experiments/{experiments[x]}")
    df['Experimento'] = [experiment_name for x in range(10)]
    data_frames.append(df)
    
frames = pd.concat(data_frames, axis=0, ignore_index=True)

# %%
print(list(frames.Experimento.unique()))
# Out:
# ['hopper_iniavg100_finavg100_1stp_Sz100', 'hopper_iniavg100_finavg33min66_1stpSz50', 'hopper_iniavg100_finavg33min66_9stpSz10', 'hopper_iniavg33min66_finavg33min66_1stpSz100', 'hopper_iniavg33min66_finavg66min33_1stpSz50', 'hopper_iniavg66min33_finavg33min66_1stpSz50']

# %%
sns.set(rc={"figure.figsize":(12, 9)}) #width=3, #height=4
ax = sns.boxplot(data=frames,
            x="Experimento",
            y="Bestgit",
            hue="Experimento",
            )
ax.set(xticklabels=[])
plt.show()
